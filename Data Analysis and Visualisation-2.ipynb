# %%
import pandas
df=pandas.read_csv('reviews.csv')
df
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                        Timestamp  Rating Comment
# 0      2021-04-02 06:25:52+00:00     4.0     NaN
# 1      2021-04-02 05:12:34+00:00     4.0     NaN
# 2      2021-04-02 05:11:03+00:00     4.0     NaN
# 3      2021-04-02 03:33:24+00:00     5.0     NaN
# ...

# %%
df['Timestamp']=pandas.to_datetime(df['Timestamp'])

# %%
df1=df.set_index('Timestamp',drop=False)

# %%
#Creating column with date attribute 
df['Day']=df['Timestamp'].dt.date

# %%
df1['Day']=df['Timestamp'].dt.date
df1
# Out:
#                                                                  Course Name  \
# Timestamp
# 2021-04-02 06:25:52+00:00  The Python Mega Course: Build 10 Real World Ap...
# 2021-04-02 05:12:34+00:00  The Python Mega Course: Build 10 Real World Ap...
# 2021-04-02 05:11:03+00:00  The Python Mega Course: Build 10 Real World Ap...
# 2021-04-02 03:33:24+00:00  The Python Mega Course: Build 10 Real World Ap...
# 2021-04-02 03:31:49+00:00  The Python Mega Course: Build 10 Real World Ap...
# ...                                                                      ...
# 2018-01-01 01:11:26+00:00                 Python for Beginners with Examples
# 2018-01-01 01:09:56+00:00  The Python Mega Course: Build 10 Real World Ap...
# 2018-01-01 01:08:11+00:00  The Python Mega Course: Build 10 Real World Ap...
# 2018-01-01 01:05:26+00:00                 Python for Beginners with Examples
# 2018-01-01 01:01:16+00:00  The Python Mega Course: Build 10 Real World Ap...
#
# ...

# %%
df_grp=df.groupby(['Day']).mean()
df_grp
# Out:
#               Rating
# Day
# 2018-01-01  4.532609
# 2018-01-02  4.122807
# 2018-01-03  4.360465
# 2018-01-04  4.531250
# 2018-01-05  4.423077
# ...              ...
# 2021-03-29  4.240000
# 2021-03-30  4.428571
# 2021-03-31  4.453125
# 2021-04-01  4.592593
# 2021-04-02  4.357143
#
# [1188 rows x 1 columns]

# %% [markdown]
# ## 3. Turning data into visualisation

# %% [markdown]
# #### Q1. What is the daily average ratings of courses ?

# %%
#Daily Rating of the course
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(20,5))
plt.plot(df_grp.index,df_grp.Rating)

# %% [markdown]
# #### Q2. What are average weekly rating of courses ?

# %%
# creating coloumn week with converting the timestamp to week 
df['Week']=df['Timestamp'].dt.strftime('%Y %U')
df
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day     Week
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13
# 2     2021-04-02 05:11:03+00:00     4.0     NaN  2021-04-02  2021 13
# ...

# %%
df_grp2=df.groupby('Week').mean()
df_grp2
# Out:
#            Rating
# Week
# 2018 00  4.434564
# 2018 01  4.424933
# 2018 02  4.417702
# 2018 03  4.401024
# 2018 04  4.468085
# ...           ...
# 2021 09  4.560096
# 2021 10  4.627315
# 2021 11  4.629121
# 2021 12  4.607843
# 2021 13  4.429032
#
# [173 rows x 1 columns]

# %%
# Weekly ratings of course
plt.figure(figsize=(30,10))
plt.plot(df_grp2.index,df_grp2.Rating)

# %% [markdown]
# #### Q3. What are average monthly rating of courses ?

# %%
# creating coloumn month with converting the timestamp to month 
df['Month']=df['Timestamp'].dt.strftime('%Y %m')
df
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day     Week    Month
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# ...

# %%
month_avg=df.groupby('Month').mean()
month_avg
# Out:
#            Rating
# Month
# 2018 01  4.429645
# 2018 02  4.436248
# 2018 03  4.421671
# 2018 04  4.468211
# 2018 05  4.396420
# 2018 06  4.375379
# 2018 07  4.393184
# 2018 08  4.344753
# 2018 09  4.347247
# 2018 10  4.374429
# 2018 11  4.386817
# 2018 12  4.342105
# 2019 01  4.401920
# 2019 02  4.346964
# 2019 03  4.333145
# 2019 04  4.420049
# 2019 05  4.405569
# 2019 06  4.398559
# 2019 07  4.382353
# 2019 08  4.417059
# 2019 09  4.451135
# 2019 10  4.483871
# 2019 11  4.493260
# 2019 12  4.471046
# 2020 01  4.439615
# 2020 02  4.428642
# 2020 03  4.480690
# 2020 04  4.475220
# 2020 05  4.448082
# 2020 06  4.482812
# 2020 07  4.517508
# 2020 08  4.470987
# 2020 09  4.485862
# 2020 10  4.515201
# 2020 11  4.479306
# 2020 12  4.528358
# 2021 01  4.551325
# 2021 02  4.567901
# 2021 03  4.589207
# 2021 04  4.544118

# %%
# Monthly ratings of course
plt.figure(figsize=(30,7.5))
plt.plot(month_avg.index,month_avg.Rating)
plt.show()

# %% [markdown]
# #### Q4. What are average monthly ratings of each course ?

# %%
df
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day     Week    Month
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# ...

# %%
monthcrs_avg=df.groupby(['Month','Course Name']).mean().unstack()
monthcrs_avg
# Out:
#                                                               Rating  \
# Course Name 100 Python Exercises I: Evaluate and Improve Your Skills
# Month
# 2018 01                                               4.353448
# 2018 02                                               4.250000
# 2018 03                                               4.500000
# 2018 04                                               4.431034
# 2018 05                                               4.358696
# 2018 06                                               4.268293
# 2018 07                                               4.589286
# 2018 08                                               4.353659
# 2018 09                                               4.238636
# 2018 10                                               4.106061
# 2018 11                                               4.212766
# 2018 12                                               4.405172
# 2019 01                                               4.048780
# ...

# %%
# Monthly ratings of every course
plt.figure(figsize=(30,5))
for i in monthcrs_avg['Rating'].columns:
    plt.plot(monthcrs_avg.index,monthcrs_avg['Rating'][i],label=i)
plt.legend()

# %%
monthcrs_avg['Rating']
# Out:
# Course Name  100 Python Exercises I: Evaluate and Improve Your Skills  \
# Month
# 2018 01                                               4.353448
# 2018 02                                               4.250000
# 2018 03                                               4.500000
# 2018 04                                               4.431034
# 2018 05                                               4.358696
# 2018 06                                               4.268293
# 2018 07                                               4.589286
# 2018 08                                               4.353659
# 2018 09                                               4.238636
# 2018 10                                               4.106061
# 2018 11                                               4.212766
# 2018 12                                               4.405172
# 2019 01                                               4.048780
# 2019 02                                               4.333333
# ...

# %% [markdown]
# #### Q5. What is happiest day of week ?

# %%
df
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day     Week    Month
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# ...

# %%
# creating coloumn weekday with converting the timestamp to days 
df['Weekday']=df['Timestamp'].dt.strftime('%A')
df
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day     Week    Month  \
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# ...

# %%
weekday_avg=df.groupby('Weekday').mean()
weekday_avg
# Out:
#              Rating
# Weekday
# Friday     4.455207
# Monday     4.449335
# Saturday   4.440274
# Sunday     4.439097
# Thursday   4.437880
# Tuesday    4.446240
# Wednesday  4.427452

# %%
days=['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
weekday_avg=weekday_avg.reindex(days)
weekday_avg
# Out:
#              Rating
# Weekday
# Sunday     4.439097
# Monday     4.449335
# Tuesday    4.446240
# Wednesday  4.427452
# Thursday   4.437880
# Friday     4.455207
# Saturday   4.440274

# %%
plt.figure(figsize=(10,5))
plt.xlabel('Days')
plt.ylabel('Rating')
plt.plot(weekday_avg.index,weekday_avg.Rating)
# It is observed that Friday is the happiest day of the week.

# %% [markdown]
# #### Q5. What are the number of ratings for each course

# %%
df
# Out:
#                                              Course Name  \
# 0      The Python Mega Course: Build 10 Real World Ap...
# 1      The Python Mega Course: Build 10 Real World Ap...
# 2      The Python Mega Course: Build 10 Real World Ap...
# 3      The Python Mega Course: Build 10 Real World Ap...
# 4      The Python Mega Course: Build 10 Real World Ap...
# ...                                                  ...
# 44995                 Python for Beginners with Examples
# 44996  The Python Mega Course: Build 10 Real World Ap...
# 44997  The Python Mega Course: Build 10 Real World Ap...
# 44998                 Python for Beginners with Examples
# 44999  The Python Mega Course: Build 10 Real World Ap...
#
#                       Timestamp  Rating Comment         Day     Week    Month  \
# 0     2021-04-02 06:25:52+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# 1     2021-04-02 05:12:34+00:00     4.0     NaN  2021-04-02  2021 13  2021 04
# ...

# %%
df_crs=df.groupby('Course Name').count()
df_crs
# Out:
#                                                     Timestamp  Rating  \
# Course Name
# 100 Python Exercises I: Evaluate and Improve Yo...       1593    1593
# 100 Python Exercises II: Evaluate and Improve Y...        280     280
# Data Processing with Python                               868     868
# Interactive Data Visualization with Python and ...        767     767
# Learn GIS in One Hour                                     499     499
# Python for Beginners with Examples                       4821    4821
# The Complete Python Course: Build 10 Profession...        470     470
# The Python Mega Course: Build 10 Real World App...      35702   35702
#
#                                                     Comment    Day   Week  \
# Course Name
# 100 Python Exercises I: Evaluate and Improve Yo...      231   1593   1593
# 100 Python Exercises II: Evaluate and Improve Y...       81    280    280
# Data Processing with Python                             117    868    868
# ...

# %%
plt.pie(df_crs.Rating,labels=df_crs.index,autopct='%0.2f%%',explode=[0.3 for i in range(len(df_crs.Rating))])
plt.show()

# %%
df_crs.loc['100 Python Exercises I: Evaluate and Improve Your Skills'].Rating
# Out:
# 1593

# %%
df_crs=df.groupby('Course Name')['Rating'].count()
df_crs
# Out:
# Course Name
# 100 Python Exercises I: Evaluate and Improve Your Skills       1593
# 100 Python Exercises II: Evaluate and Improve Your Skills       280
# Data Processing with Python                                     868
# Interactive Data Visualization with Python and Bokeh            767
# Learn GIS in One Hour                                           499
# Python for Beginners with Examples                             4821
# The Complete Python Course: Build 10 Professional OOP Apps      470
# The Python Mega Course: Build 10 Real World Applications      35702
# Name: Rating, dtype: int64

# %%
list(df_crs)
# Out:
# [1593, 280, 868, 767, 499, 4821, 470, 35702]
